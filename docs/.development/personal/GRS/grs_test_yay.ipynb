# %%
# import redplanet
from redplanet import GRS

# %%
# help(GRS)
print(f"k concentration: \t\t{GRS.get_pt('k', lon=0, lat=10) :.8f}")
print(f"k concentration normalized: \t{GRS.get_pt('k', lon=0, lat=10, normalize=True) :.8f}")
print(f"k sigma: \t\t\t{GRS.get_pt('k', lon=0, lat=10, quantity='sigma') :.8f}")
print(f"k sigma normalized: \t\t{GRS.get_pt('k', lon=0, lat=10, quantity='sigma', normalize=True) :.8f}")
# Out:
# k concentration: 		0.00353002
# k concentration normalized: 	0.00388616
# k sigma: 			0.00010849
# k sigma normalized: 		0.00010940

# %%
import numpy as np
import matplotlib.pyplot as plt

lons = np.arange(-180,180,1)
lats = np.arange(-90,90,1)

dat = GRS.get_region('k', lons=lons, lats=lats)

plt.imshow(dat)

# %%
dat_grs_xarr = GRS.get_rawdata('xarray')

dat_grs_xarr
# Out:
# <xarray.Dataset> Size: 416kB
# Dimensions:        (element: 10, lat: 36, lon: 72)
# Coordinates:
#   * element        (element) object 80B 'al' 'ca' 'cl' ... 'si' 'th' 'volatiles'
#   * lat            (lat) float64 288B -87.5 -82.5 -77.5 -72.5 ... 77.5 82.5 87.5
#   * lon            (lon) float64 576B -177.5 -172.5 -167.5 ... 167.5 172.5 177.5
# Data variables:
#     concentration  (element, lat, lon) float64 207kB nan nan nan ... nan nan nan
#     sigma          (element, lat, lon) float64 207kB nan nan nan ... nan nan nan
